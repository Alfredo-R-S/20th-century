# %% [markdown]
# # 20th Century Text Mining Task
#
# * Libraries imported
# * Data Loaded
# * Tokenization
# * Stop Words
# * POS Tags with TextBlob
# * Nouns
# * Verbs
# * Adjectives
# * Top Countries
# * Sentiment Analysis

# %% [markdown]
# Install the necessary libraries from the requirements.txt file into your corresponding virtual environment. Make sure you start JupyterLab with the extra data rate argument.Install the necessary libraries from the requirements.txt file into your corresponding virtual environment. Make sure you start JupyterLab with the extra data rate argument.

# %% [markdown]
# # Libraries imported

# %%
# Librarires are imported
from textblob import TextBlob 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Data Loaded

# %% [markdown]
# Load the twentieth-century data that you scraped in Exercise 1.4.

# %%
myfile = open('20th_Century_Wewbpage.txt', encoding='utf-8')

# %%
# Import txt file

with open('20th_Century_Wewbpage.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %% [markdown]
# # Tokenization

# %% [markdown]
# Tokenize the words from the text and create a bar chart to plot the 10 most common words.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Sentence tokenization 

from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ['Key events of the 20th century - WikipediaJump to contentMain menuMain menumove to sidebarhide\t\tNavigation\tMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\t\tContribute\tHelpLearn to editCommunity portalRecent changesUpload fileSpecial pagesSearchSearchAppearanceDonateCreate accountLog inPersonal toolsDonate Create account Log in\t\tPages for logged out editors learn moreContributionsTalkContentsmove to sidebarhide(Top)1Historic events in the 20th centuryToggle Historic events in the 20th century subsection1.1World at the beginning of the century1.1.1"The war to end all wars": World War I (1914–1918)1.2Spanish flu1.2.1Russian Revolution and communism1.3Between the wars1.3.1Economic depression1.3.2The rise of dictatorship1.4Global war: World War II (1939–1945)1.4.1The war in Europe1.4.2Blitzkrieg1.4.3Operation Barbarossa1.4.4Turning tides1.4.5Operation Overlord1.4.6Final days1.4.7The war in the Pacific1.4.7.1Background1.4.8Japanese Expansion1.4.9Allied offe
# ...

# %%
# Word tokenization

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['Key', 'events', 'of', 'the', '20th', 'century', '-', 'WikipediaJump', 'to', 'contentMain', 'menuMain', 'menumove', 'to', 'sidebarhide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'to', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSpecial', 'pagesSearchSearchAppearanceDonateCreate', 'accountLog', 'inPersonal', 'toolsDonate', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'moreContributionsTalkContentsmove', 'to', 'sidebarhide', '(', 'Top', ')', '1Historic', 'events', 'in', 'the', '20th', 'centuryToggle', 'Historic', 'events', 'in', 'the', '20th', 'century', 'subsection1.1World', 'at', 'the', 'beginning', 'of', 'the', 'century1.1.1', "''", 'The', 'war', 'to', 'end', 'all', 'wars', "''", ':', 'World', 'War', 'I', '(', '1914–1918', ')', '1.2Spanish', 'flu1.2.1Russian', 'Revolution', 'and', 'communism1.3Between', 'the', 'wars1.3.1Economic', 'depression
# ...

# %%
# Create frequency distribution

from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 4915 samples and 21412 outcomes>

# %%
dist_words.most_common(10)
# Out:
# [('.', 1314),
#  ('the', 1132),
#  (',', 975),
#  ('of', 626),
#  ('and', 410),
#  ('to', 333),
#  ('[', 309),
#  (']', 309),
#  ('in', 303),
#  ('The', 301)]

# %%
# Plot the 30 most common words
plt.figure(figsize=(12, 6))
nltk.FreqDist(tokenized_word).plot(30, cumulative=False)
plt.show()

# %% [markdown]
# # Stop Words

# %% [markdown]
# Remove stop words (and punctuation marks if necessary), and rerun the plot. What has changed? Comment on your impressions in a markdown cell under the plot.

# %%
# Defining stopwords

from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'hers', 'yourselves', 'ours', 'very', 'through', 'does', "shan't", 'd', 'shan', 'isn', 'mustn', 're', 'that', 'ma', 'aren', 'there', 'his', 'my', 'of', 'can', 'other', 'it', 'a', "we'd", 'were', 'your', 'on', 'having', 'don', 'hasn', 'myself', 'so', 'too', 'into', 'doesn', "i'd", 'which', 'no', 'further', 'been', "she'll", "it's", "i'll", "they'd", 'ain', 'haven', 'the', "he'd", 'himself', 'has', 'only', 'off', 'what', 'same', 'by', "needn't", 'being', 'where', 'are', 'more', 'won', 'each', "shouldn't", 'our', 'wasn', "wouldn't", 'both', 'during', 'how', 'or', "they've", 'between', "didn't", 'theirs', 'doing', 'with', 'an', 'against', "she'd", "they're", "you'd", "that'll", 'now', 'mightn', 'from', "he'll", "hadn't", "aren't", 'about', 'most', 'but', 'needn', 'should', 'have', "we're", 'than', 'after', 'yours', "it'll", 'as', 'under', 'her', "wasn't", 'then', 'not', 'themselves', 'you', 'yourself', 'when', 'be', 'for', 'all', "isn't", "you're", 'll', 'up', "weren't", 'didn', 'own', 
# ...

# %%
# Removing stopwords in sentences

# filtered_sent = []
# for word in tokenized_sent:
#     if word not in stop_words:
#         filtered_sent.append(word)
# print("Tokenized Sentence:", tokenized_sent)
# print("Filterd Sentence:", filtered_sent)

# %%
# Removing stopwords in words

filtered_words = [] # creates an empty list
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)

# %%
filtered_words
# Out:
# ['Key',
#  'events',
#  '20th',
#  'century',
#  '-',
#  'WikipediaJump',
#  'contentMain',
#  'menuMain',
#  'menumove',
#  'sidebarhide',
#  'Navigation',
#  'Main',
#  'pageContentsCurrent',
#  'eventsRandom',
#  'articleAbout',
#  'WikipediaContact',
#  'us',
#  'Contribute',
#  'HelpLearn',
#  'editCommunity',
#  'portalRecent',
#  'changesUpload',
#  'fileSpecial',
#  'pagesSearchSearchAppearanceDonateCreate',
#  'accountLog',
#  'inPersonal',
#  'toolsDonate',
#  'Create',
#  'account',
#  'Log',
#  'Pages',
#  'logged',
#  'editors',
#  'learn',
#  'moreContributionsTalkContentsmove',
#  'sidebarhide',
#  '(',
#  'Top',
#  ')',
#  '1Historic',
#  'events',
#  '20th',
#  'centuryToggle',
#  'Historic',
#  'events',
#  '20th',
#  'century',
#  'subsection1.1World',
#  'beginning',
#  'century1.1.1',
#  "''",
#  'The',
#  'war',
#  'end',
#  'wars',
#  "''",
#  ':',
#  'World',
#  'War',
#  'I',
#  '(',
#  '1914–1918',
#  ')',
#  '1.2Spanish',
#  'flu1.2.1Russian',
# ...

# %%
# Create a new FreqDist for filtered_words

dist_words_filter = FreqDist(filtered_words)
print(dist_words_filter)
# Out:
# <FreqDist with 4811 samples and 16632 outcomes>

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words_filter.plot(10, cumulative = False)
plt.show()

# %%
dist_words_filter
# Out:
# FreqDist({'.': 1314, ',': 975, '[': 309, ']': 309, 'The': 301, "''": 278, '``': 272, '(': 260, ')': 260, 'December': 223, ...})

# %%
# Substitute all punctuations marks with a space 

sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                          " ",          # Replace all non-letters with spaces
                          str(filtered_words))

# %%
sans_punc
# Out:
# '  Key    events      th    century         WikipediaJump    contentMain    menuMain    menumove    sidebarhide    Navigation    Main    pageContentsCurrent    eventsRandom    articleAbout    WikipediaContact    us    Contribute    HelpLearn    editCommunity    portalRecent    changesUpload    fileSpecial    pagesSearchSearchAppearanceDonateCreate    accountLog    inPersonal    toolsDonate    Create    account    Log    Pages    logged    editors    learn    moreContributionsTalkContentsmove    sidebarhide         Top          Historic    events      th    centuryToggle    Historic    events      th    century    subsection   World    beginning    century               The    war    end    wars               World    War    I                              Spanish    flu     Russian    Revolution    communism   Between    wars     Economic    depression     The    rise    dictatorship   Global    war         World    War    II                                The    war    Europe     Bli
# ...

# %%
# Word tokenization

tokenized_word_2 = word_tokenize(sans_punc)
print(tokenized_word_2)
# Out:
# ['Key', 'events', 'th', 'century', 'WikipediaJump', 'contentMain', 'menuMain', 'menumove', 'sidebarhide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSpecial', 'pagesSearchSearchAppearanceDonateCreate', 'accountLog', 'inPersonal', 'toolsDonate', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'moreContributionsTalkContentsmove', 'sidebarhide', 'Top', 'Historic', 'events', 'th', 'centuryToggle', 'Historic', 'events', 'th', 'century', 'subsection', 'World', 'beginning', 'century', 'The', 'war', 'end', 'wars', 'World', 'War', 'I', 'Spanish', 'flu', 'Russian', 'Revolution', 'communism', 'Between', 'wars', 'Economic', 'depression', 'The', 'rise', 'dictatorship', 'Global', 'war', 'World', 'War', 'II', 'The', 'war', 'Europe', 'Blitzkrieg', 'Operation', 'Barbarossa', 'Turning', 'tides', 'Operation', 'Overlord', 'Final', 'days', 'The',
# ...

# %%
# Create a new FreqDist

dist_words_filter_2 = FreqDist(tokenized_word_2)

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words_filter_2.plot(30, cumulative = False)
plt.show()

# %%
dist_words_filter_2.most_common(10)
# Out:
# [('The', 322),
#  ('December', 223),
#  ('Retrieved', 207),
#  ('War', 127),
#  ('s', 100),
#  ('war', 92),
#  ('th', 87),
#  ('World', 78),
#  ('Soviet', 62),
#  ('Hitler', 50)]

# %% [markdown]
# # Initially, the most common words were ('.', 1311), ('the', 1132), and (',', 975), which are not meaningful for analysis.
# # After removing stop words and punctuation marks, the new most common words are ('The', 322), ('December', 223), and ('Retrieved', 207), which offer more meaningful insights for analysis. However, "The" still appears as the most frequent word, indicating that further cleaning is needed, as it does not contribute useful information.

# %% [markdown]
# # POS Tags with TextBlob

# %% [markdown]
# * Create a tags list using TextBlob
# * Create a list of the Top 10 POS tags for words that appear in the article.
# * Plot this list in a bar chart using the seaborn library.

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The']

# %%
filtered = []
for word in tokenized_word_2:
    if word not in new_stopwords:
        filtered.append(word)

# %%
# %%time
text = TextBlob(str(filtered))
# Out:
# CPU times: total: 0 ns
# Wall time: 7.18 ms

# %%
text
# Out:
# TextBlob("['Key', 'events', 'th', 'century', 'WikipediaJump', 'contentMain', 'menuMain', 'menumove', 'sidebarhide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSpecial', 'pagesSearchSearchAppearanceDonateCreate', 'accountLog', 'inPersonal', 'toolsDonate', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'moreContributionsTalkContentsmove', 'sidebarhide', 'Top', 'Historic', 'events', 'th', 'centuryToggle', 'Historic', 'events', 'th', 'century', 'subsection', 'World', 'beginning', 'century', 'war', 'end', 'wars', 'World', 'War', 'I', 'Spanish', 'flu', 'Russian', 'Revolution', 'communism', 'Between', 'wars', 'Economic', 'depression', 'rise', 'dictatorship', 'Global', 'war', 'World', 'War', 'II', 'war', 'Europe', 'Blitzkrieg', 'Operation', 'Barbarossa', 'Turning', 'tides', 'Operation', 'Overlord', 'Final', 'days', 'war', 'Pacific',
# ...

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
tags_list = text.tags

# %%
tags_list
# Out:
# [('[', 'JJ'),
#  ("'Key", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'WikipediaJump", 'NNP'),
#  ("'", 'POS'),
#  ("'menumove", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebarhide", 'NNP'),
#  ("'", 'POS'),
#  ("'Navigation", 'NN'),
#  ("'pageContentsCurrent", 'NNP'),
#  ("'", 'POS'),
#  ("'eventsRandom", 'NNP'),
#  ("'", 'POS'),
#  ("'articleAbout", 'IN'),
#  ("'WikipediaContact", 'NNP'),
#  ("'", 'POS'),
#  ("'us", 'NNP'),
#  ("'", 'POS'),
#  ("'HelpLearn", 'NNP'),
#  ("'", 'POS'),
#  ("'editCommunity", 'NNP'),
#  ("'", 'POS'),
#  ("'portalRecent", 'NNP'),
#  ("'", 'POS'),
#  ("'fileSpecial", 'NNP'),
#  ("'", 'POS'),
#  ("'pagesSearchSearchAppearanceDonateCreate", 'NNP'),
#  ("'", 'POS'),
#  ("'accountLog", 'NNP'),
#  ("'", 'POS'),
#  ("'inPersonal", 'NNP'),
#  ("'", 'POS'),
#  ("'toolsDonate", 'NNP'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
# ...

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = ['Words', "Word type"]

# %%
df_text.head()
# Out:
#      Words Word type
# 0        [        JJ
# 1     'Key       NNP
# 2        '       POS
# 3  'events       NNS
# 4        '       POS

# %%
df_t = df_text.groupby('Word type').count().reset_index()

# %%
df_t.head()
# Out:
#   Word type  Words
# 0        CC      1
# 1        CD     78
# 2        DT     12
# 3        EX     13
# 4        FW     43

# %%
top10 = df_t.nlargest(10, 'Words')

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 20):
    sns.barplot(x = "Words", y = "Word type",
    saturation = 0.9, data = top10).set_title("20th Century - top 10 word types used")

# %% [markdown]
# Create three bar plots with the top 15 POS labels—one each for nouns, verbs, and adjectives. Analyzing the results—what do you think stands out in these frequencies? Comment on your impressions in a Markdown cell under the plot.

# %% [markdown]
# # Nouns

# %%
df = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNP")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
top15
# Out:
#            Word  Occurences
# 300   'December         223
# 1294       'War         127
# 2660       'war          92
# 2579        'th          87
# 1344     'World          78
# 1141    'Soviet          62
# 555     'Hitler          50
# 581       'ISBN          43
# 554    'History          42
# 1831     'first          41
# 2687     'world          39
# 1537   'century          37
# 489     'German          35
# 592         'In          35
# 1737      'edit          34

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data = top15).set_title("20th Century - Top 15 frequently used nouns")

# %% [markdown]
# By analyzing this set of words, it is possible to deduce that one of the most prominent topics in the 20th century was the World Wars, particularly World War II.

# %% [markdown]
# # Verbs

# %%
df = df_text[(df_text['Word type'] == "VB")  | (df_text['Word type'] == "VBD")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
top15
# Out:
#              Word  Occurences
# 28     'Retrieved         207
# 37        'United          31
# 0         'Allied          19
# 196          'led          15
# 323         'used          13
# 1       'Archived          12
# 194     'launched          12
# 93    'controlled           9
# 160       'forced           8
# 306  'surrendered           7
# 77       'changed           7
# 315       'turned           7
# 139        'ended           6
# 75        'caused           6
# 233      'planned           6

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x = "Word", y = "Occurences",
    saturation = 0.9, data = top15).set_title("20th Century - Top 15 frequently used verbs")

# %% [markdown]
# By examining the full text on the webpage, it becomes clear why the word "Retrieved" is among the most common, it appears frequently in the References section.

# %% [markdown]
# # Adjectives

# %%
df = df_text[df_text['Word type'] == "JJ"]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by=['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
top15
# Out:
#             Word  Occurences
# 27     'Japanese          36
# 2      'American          24
# 5      'Atlantic          13
# 19     'Guardian          10
# 42      'Russian           7
# 13      'Chinese           7
# 1       'African           6
# 106   'political           6
# 107    'possible           5
# 7        'Baltic           5
# 94      'medical           5
# 51        'These           4
# 9         'Brian           4
# 6    'Australian           4
# 26      'Italian           4

# %%
plt.figure(figsize=(13, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data=top15).set_title("20th Century - Top 15 frequently used verbs Adjectives")

# %% [markdown]
# The most common adjectives are closely related to the main topic of the webpage, which is World War II.

# %% [markdown]
# # Top Countries

# %% [markdown]
# Create a dataframe with the countries and the number of times they’re mentioned in your text (remember—you’ll need to use the countries lookup list if you didn’t scrape one in the previous task).

# %% [markdown]
# Create a plot showing the frequency of the number of times these countries are mentioned in the text. Is there anything in particular you notice in this plot? Describe your findings in a Markdown cell underneath the plot.

# %%
import pycountry
import re
from collections import Counter

# Load your text
with open("20th_Century_Wewbpage.txt", "r", encoding="utf-8") as file:
    text = file.read()

# Get list of all country names using pycountry
countries = [country.name for country in pycountry.countries]

# Optional: add alternative/common names or abbreviations
extra_countries = ['USA', 'UK', 'U.S.', 'U.S.A.', 'United States',  'Russia', 'Soviet Union']
countries += extra_countries

# Use regex to tokenize text by words (preserve capitalization for matching)
tokens = re.findall(r'\b[A-Z][a-zA-Z.]+\b', text)

# Filter tokens that match known country names
matched_countries = [token for token in tokens if token in countries]

# Count occurrences
country_counts = Counter(matched_countries)

# Print results
for country, count in country_counts.most_common(15):
    print(f"{country}: {count}")
# Out:
# Germany: 42
# Japan: 33
# France: 17
# Italy: 14
# Poland: 13
# China: 10
# Russia: 9
# India: 9
# Austria: 5
# Norway: 5
# Libya: 5
# Philippines: 5
# Finland: 4
# Greece: 4
# Guinea: 4

# %%
df = pd.DataFrame(country_counts.items(), columns=['Country', 'Occurrences'])
df = df.sort_values(by='Occurrences', ascending=False).head(10)  # Top 10

plt.figure(figsize=(10, 6))
plt.bar(df['Country'], df['Occurrences'], color='black')
plt.xticks(rotation=45, ha='right')
plt.title("Top 10 Country Name Occurrences")
plt.xlabel("Country")
plt.ylabel("Occurrences")
plt.tight_layout()
plt.show()

# %% [markdown]
# This plot shows that the countries with the highest number of occurrences are those that were involved in the World Wars of the 20th century.

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# Based on the general topics in the article I belive the Sentiment scores would be:
# - Polarity = Negative, so close to -1
# - Subjectivity = Factual Information, so close to 0.

# %%
text_sent = TextBlob(str(filtered))
print(text_sent.sentiment)
# Out:
# Sentiment(polarity=0.049329443685284545, subjectivity=0.35493327785167)

# %% [markdown]
# The test results show a polarity of 0.04, indicating that the text is neither strongly negative nor positive.
# The subjectivity score is 0.35, suggesting that the text contains more factual information than personal opinions.

# %%
df
# Out:
#     Country  Occurrences
# 6   Germany           42
# 27    Japan           33
# 2    France           17
# 8     Italy           14
# 10   Poland           13
# 30    China           10
# 5    Russia            9
# 37    India            9
# 19   Norway            5
# 3   Austria            5

# %%
df.Country
# Out:
# 6     Germany
# 27      Japan
# 2      France
# 8       Italy
# 10     Poland
# 30      China
# 5      Russia
# 37      India
# 19     Norway
# 3     Austria
# Name: Country, dtype: object

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#    Country  Occurrences
# 0  Germany           42
# 1    Japan           33
# 2   France           17
# 3    Italy           14
# 4   Poland           13
# 5    China           10
# 6   Russia            9
# 7    India            9
# 8   Norway            5
# 9  Austria            5

# %%
df.to_csv('country_list_20th_century.csv', index=False)
